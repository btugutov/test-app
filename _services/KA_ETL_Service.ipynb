# %%
## From SQL to DataFrame Pandas
import pandas as pd
import pyodbc
import json

# %%
# START CONFIG
# SET ALL OF THE THINGS HERE!!!
# Read in the credentials
with open("ka_creds.json") as f:
    credentials = json.load(f)

# what tables will we be reading from
ka_table = '[dbo].[KA_employee_TEST]'
bp_table = '[dbo].[tblEmployee]'

bp_columns = '''
[FirstName],
[LastName],
[Title],
[Team],
[SeperationDate],
[Email],
[Specialization],
[WFMID],
[Specialization2],
[Specialization3]
'''
ka_columns = '''
[first_name],
[last_name],
[title],
[team],
[separation_date],
[email],
[specialization],
[wfm_id],
[specialization2],
[specialization3]
'''
values = '?,?,?,?,?,?,?,?,?,?'

#bp_query = 'SELECT ' + bp_columns + ' FROM ' + bp_table + ' WHERE Email IS NOT NULL'
bp_query = 'SELECT ' + bp_columns + ' FROM ' + bp_table
ka_query = 'SELECT ' + ka_columns + ' FROM ' + ka_table

# END CONFIG

# %%
def log(db,event,level='INFO'):
    '''
    Parameters
    ----------
    level : INFO DEBUG WARNING ERROR
    '''
    webapp = 'KA ETL Service'
    ka_log = '[dbo].[KA_log]'
    log_columns = '''
    [log_level],[log_event],[webapp]
    '''
    log_cursor = db.cursor()
    
    log_cursor.execute("INSERT INTO "+ka_log+"("+log_columns+") VALUES (?,?,?)",
                       level,
                       event,
                       webapp)
    log_cursor.commit()
    log_cursor.close()

# %%
class Database:
    def __init__(self,db,server,user,pw):
        self.db = db
        self.server = server
        self.user = user
        self.pw = pw
    def connect(self):
        #print('connecting to '+self.db)
        conn = pyodbc.connect('DRIVER={SQL Server}; SERVER='+self.server+'; DATABASE='+self.db+'; UID='+self.user+'; PWD='+self.pw)
        return conn
    def query(self,select,table,where):
        print("this does not work yet... please ignore the broken everything...it's just a outward reflection of my innerself...What?")
        s = 'SELECT '+select
        q = select+table+where
        r = pd.read_sql(q,self.connect())
        return r
    def cursor(self):
        #print('Creating cursor for :'+self.db)
        conn = self.connect()
        return conn.cursor()
    def commit(self):
        #print('Running commit for :'+self.db)
        conn = self.connect()
        conn.commit()
    def disconnect(self):
        conn = self.connect()
        conn.close()

# %%
bp_db = Database(credentials['bp_database'],credentials['bp_server'],credentials['bp_username'],credentials['bp_pass'])
ka_db = Database(credentials['ka_database'],credentials['ka_server'],credentials['ka_username'],credentials['ka_pass'])

# %%
# def log(db,event,level='info'):
log(ka_db,str("Starting script to update :"+ka_table), "INFO")

bp_df = pd.read_sql(bp_query, bp_db.connect())
ka_df = pd.read_sql(ka_query, ka_db.connect())

# %%
# make the BP version of things fit the Knowledge assessment version of things
bp_df = bp_df.rename(index=str, columns={"FirstName":"first_name","LastName":"last_name","SeperationDate":"separation_date","WFMID":"wfm_id"})
bp_df = bp_df.rename(str.lower, axis='columns')

# %%
# for test existing table has 5 items and new table has 15
# 5 should be update # 10 should be insert
#bp_df = bp_df.head(5) # testing. comment out for real

ka_df_insert = bp_df.merge(ka_df, on=['wfm_id'], how='left', suffixes=('', '_ka')) # join left on ka table
ka_df_insert = ka_df_insert[ka_df_insert['email_ka'].isin([pd.np.NaN])]  # clear out rows that exist in KA table

ka_df_update = bp_df.merge(ka_df, on=['wfm_id'], how='right', suffixes=('', '_ka')) # Join right on wfm table
ka_df_update = ka_df_update[~ka_df_update['email'].isin([pd.np.NaN])]  # clear out rows that exist in KA table

# %%
#ka_df_insert
ka_df_update
# Out:
#     first_name         last_name                    title          team  \
# 0        Dylan            Nelson                     Tech         ESC 6
# 1        Irina           Majougo                     Tech            19
# 2     Xinglong                Li                     Tech         ESC 7
# 3         Mike            Mcghee  Sr. Support Coordinator            SC
# 4        Armen         Grigoryan                     Tech            15
# 5     Emanuela             Serpi                     Tech         ESC 6
# 6         Alsu         Shakirova        Localization Lead  Localization
# 7       Robert           Preston                     Tech         ESC 8
# 8       Ruslan            Sharan                     Tech         ESC 5
# 9         Seth           Hawkins                Team Lead             2
# 10      Yuliya         Bulhayeva        Quality Team Lead            QM
# 11      Monica             Zhang                     Tech         ESC 5
# 12      Moises    Servin Robledo                     Tech            17
# 13     Jessica            Larson      Hardware Specialist      Hardware
# 14        John           Simpson                  Sr. OPM           OPM
# 15    Marianna         Biryukova                     Tech         ESC 1
# 16     Lisbeth           Grayson                     Tech            10
# 17        Olga        Zolotarova                     Tech         ESC 3
# 18    Jon-Eric           Swigart                Team Lead        DOTA 1
# 19       Katie         Baranchuk                      OPM           OPM
# 20      Angela               Wei                     Tech         ESC 5
# 21        Drew            Wilkes                     Tech         ESC 6
# 22     Jessica             Jones                      OPM           OPM
# 23       Mindy              Zhou                     Tech         ESC 5
# 24        Qing              Chen                     Tech        DOTA 1
# 25      Travis           Whitney                     Tech            19
# 26      Weilie              Chen                       BI            BI
# 27         Yan                He                     Tech         ESC 5
# 28   Alexandra         Sergueeva                     Tech         ESC 5
# 29       Uschi   Fischer Marques                Team Lead            16
# ..         ...               ...                      ...           ...
# 647      Ahmed         Abdullahi      Hardware Specialist      Hardware
# 648        Nik          Kazaklis      Hardware Specialist      Hardware
# 649       John           Sharkey      Hardware Specialist      Hardware
# 650  Ping-Yuan              Wang  Localization Specialist  Localization
# 651       Sara           Glaeser  Localization Specialist  Localization
# 652      Eriko           Gardner  Localization Specialist  Localization
# 653    Natalia            Kopysc                     Tech             8
# 654     Enrico       Tartaglione                     Tech             8
# 655    Adriana   Pereira de Lima                     Tech            11
# 656     Rasmus         Rasmussen                     Tech             8
# 657     Roxana           Ascanio                     Tech             4
# 658      Pablo  Espinoza Ordonez                     Tech            10
# 659      Kevin            Sooter                     Tech             5
# 660       Bart          Rogowski                     Tech            10
# 661      Sarah             Hakim                     Tech            10
# 662       Faig          Naghiyev          Quality Analyst            QM
# 663      Olena            Skoryk          Quality Analyst            QM
# 664     Fergie         Rodriguez          Quality Analyst            QM
# 665       Mary               Mei          Quality Analyst            QM
# 666     Stefan             Radke          Quality Analyst            QM
# 667      Megan            Harris  Localization Specialist  Localization
# 668    Barbara            Coplen               BI Analyst            BI
# 669    Mariana              Dias                     Tech             7
# 670     Camila          DiNicola                     Tech             5
# 671    Barbara           Cozzari  Localization Specialist  Localization
# 672      Hilal             Altug                     Tech             5
# 673    Mariana          Carneiro  Localization Specialist  Localization
# 674     Anders         Sandkvist  Localization Specialist  Localization
# 675   Sirithip            French                     Tech             6
# 676   Santiago         Hernandez                     Tech            11
#
#     separation_date                      email   specialization  wfm_id  \
# 0              None           dnelson@bpcs.com            Fraud     BP5
# 1              None          imajougo@bpcs.com  Unknown Charges     BP6
# 2              None               xli@bpcs.com             Tech     BP8
# 3              None           mmcghee@bpcs.com         Accounts     BP9
# 4              None        agrigoryan@bpcs.com     Call Logging    BP11
# 5              None            eserpi@bpcs.com            Fraud    BP15
# 6              None        ashakirova@bpcs.com             None    BP16
# 7              None          rpreston@bpcs.com             Tech    BP17
# 8              None           rsharan@bpcs.com          Billing    BP18
# 9              None          shawkins@bpcs.com             Tech    BP19
# 10             None        ybulhayeva@bpcs.com         Accounts    BP20
# 11             None            yzhang@bpcs.com          Billing    BP21
# 12             None          mrobledo@bpcs.com  Unknown Charges    BP23
# 13             None           jlarson@bpcs.com         Hardware    BP24
# 14             None          jsimpson@bpcs.com         Accounts    BP25
# 15       2018-11-27        mbiryukova@bpcs.com         Accounts    BP27
# 16       2018-06-15          lgrayson@bpcs.com         Accounts    BP28
# 17             None             ozolo@bpcs.com          Billing    BP29
# 18             None         jeswigart@bpcs.com             Dota    BP30
# 19             None        kbaranchuk@bpcs.com          Billing    BP32
# 20       2018-06-21              awei@bpcs.com          Billing    BP34
# 21             None           dwilkes@bpcs.com            Fraud    BP35
# 22             None            jjones@bpcs.com             None    BP37
# 23             None             mzhou@bpcs.com          Billing    BP38
# 24             None             qchen@bpcs.com             Dota    BP39
# 25             None          twhitney@bpcs.com          Billing    BP41
# 26       2018-05-29             wchen@bpcs.com             None    BP42
# 27             None               yhe@bpcs.com          Billing    BP43
# 28       2018-06-28        asergueeva@bpcs.com          Billing    BP44
# 29             None          umarques@bpcs.com          Billing    BP45
# ..              ...                        ...              ...     ...
# 647            None        aabdullahi@bpcs.com         Hardware  BP1168
# 648            None         nkazaklis@bpcs.com         Hardware  BP1169
# 649            None          jsharkey@bpcs.com         Hardware  BP1170
# 650            None             pwang@bpcs.com                   BP1171
# 651            None          sglaeser@bpcs.com                   BP1172
# 652            None          egardner@bpcs.com                   BP1173
# 653            None           nkopysc@bpcs.com         Accounts  BP1175
# 654            None      etartaglione@bpcs.com         Accounts  BP1176
# 655            None    Apereiradelima@bpcs.com         Accounts  BP1178
# 656            None        rrasmussen@bpcs.com         Accounts  BP1179
# 657            None   roascanioandara@bpcs.com         Accounts  BP1180
# 658            None  Pespinozaordonez@bpcs.com         Accounts  BP1181
# 659            None           ksooter@bpcs.com         Accounts  BP1182
# 660            None         brogowski@bpcs.com         Accounts  BP1183
# 661      2019-02-14            shakim@bpcs.com         Accounts  BP1184
# 662            None         fnaghiyev@bpcs.com         Accounts  BP1185
# 663            None           oskoryk@bpcs.com         Accounts  BP1186
# 664            None        frodriguez@bpcs.com         Accounts  BP1187
# 665            None              mmei@bpcs.com         Accounts  BP1188
# 666            None            sradke@bpcs.com         Accounts  BP1189
# 667            None           mharris@bpcs.com                   BP1190
# 668            None           bcoplen@bpcs.com                   BP1191
# 669            None             mdias@bpcs.com         Accounts  BP1192
# 670            None         cdinicola@bpcs.com         Accounts  BP1193
# 671            None          bcozzari@bpcs.com             Null  BP1194
# 672            None            haltug@bpcs.com         Accounts  BP1195
# 673            None         mcarneiro@bpcs.com             Null  BP1197
# 674            None        asandqvist@bpcs.com             Null  BP1198
# 675            None           sfrench@bpcs.com         Accounts  BP1199
# 676            None        shernandez@bpcs.com         Accounts  BP1200
#
#      specialization2 specialization3 first_name_ka      last_name_ka  \
# 0               None            None         Dylan            Nelson
# 1               None            None         Irina           Majougo
# 2               None            None      Xinglong                Li
# 3               None            None          Mike            Mcghee
# 4    Unknown Charges            None         Armen         Grigoryan
# 5               None            None      Emanuela             Serpi
# 6               None            None          Alsu         Shakirova
# 7               None            None        Robert           Preston
# 8               None            None        Ruslan            Sharan
# 9            Billing            None          Seth           Hawkins
# 10              None            None        Yuliya         Bulhayeva
# 11              None            None        Monica             Zhang
# 12      Call Logging            None        Moises    Servin Robledo
# 13              None            None       Jessica            Larson
# 14              None            None          John           Simpson
# 15              None            None      Marianna         Biryukova
# 16              None            None       Lisbeth           Grayson
# 17              None            None          Olga        Zolotarova
# 18             Merch            None      Jon-Eric           Swigart
# 19              None            None         Katie         Baranchuk
# 20              None            None        Angela               Wei
# 21           Billing            None          Drew            Wilkes
# 22              None            None       Jessica             Jones
# 23              None            None         Mindy              Zhou
# 24          Artifact           Merch          Qing              Chen
# 25              None            None        Travis           Whitney
# 26              None            None        Weilie              Chen
# 27              None            None           Yan                He
# 28              None            None     Alexandra         Sergueeva
# 29              None            None         Uschi   Fischer Marques
# ..               ...             ...           ...               ...
# 647             None            None         Ahmed         Abdullahi
# 648          Billing            None           Nik          Kazaklis
# 649          Billing            None          John           Sharkey
# 650             None            None     Ping-Yuan              Wang
# 651             None            None          Sara           Glaeser
# 652             None            None         Eriko           Gardner
# 653             None            None       Natalia            Kopysc
# 654             None            None        Enrico       Tartaglione
# 655             None            None       Adriana   Pereira de Lima
# 656             None            None        Rasmus         Rasmussen
# 657             None            None        Roxana           Ascanio
# 658             None            None         Pablo  Espinoza Ordonez
# 659             None            None         Kevin            Sooter
# 660             None            None          Bart          Rogowski
# 661             None            None         Sarah             Hakim
# 662             None            None          Faig          Naghiyev
# 663             None            None         Olena            Skoryk
# 664             None            None        Fergie         Rodriguez
# 665             None            None          Mary               Mei
# 666             None            None        Stefan             Radke
# 667             None            None         Megan            Harris
# 668             None            None       Barbara            Coplen
# 669             None            None       Mariana              Dias
# 670             None            None        Camila          DiNicola
# 671             None            None       Barbara           Cozzari
# 672             None            None         Hilal             Altug
# 673             None            None       Mariana          Carneiro
# 674             None            None        Anders         Sandkvist
# 675             None            None      Sirithip            French
# 676             None            None      Santiago         Hernandez
#
#                     title_ka       team_ka separation_date_ka  \
# 0                       Tech         ESC 6               None
# 1                       Tech            19               None
# 2                       Tech         ESC 7               None
# 3    Sr. Support Coordinator            SC               None
# 4                       Tech            15               None
# 5                       Tech         ESC 6               None
# 6          Localization Lead  Localization               None
# 7                       Tech         ESC 8               None
# 8                       Tech         ESC 5               None
# 9                  Team Lead             2               None
# 10         Quality Team Lead            QM               None
# 11                      Tech         ESC 5               None
# 12                      Tech            17               None
# 13       Hardware Specialist      Hardware               None
# 14                   Sr. OPM           OPM               None
# 15                      Tech         ESC 1         2018-11-27
# 16                      Tech            10         2018-06-15
# 17                      Tech         ESC 3               None
# 18                 Team Lead        DOTA 1               None
# 19                       OPM           OPM               None
# 20                      Tech         ESC 5         2018-06-21
# 21                      Tech         ESC 6               None
# 22                       OPM           OPM               None
# 23                      Tech         ESC 5               None
# 24                      Tech        DOTA 1               None
# 25                      Tech            19               None
# 26                        BI            BI         2018-05-29
# 27                      Tech         ESC 5               None
# 28                      Tech         ESC 5         2018-06-28
# 29                 Team Lead            16               None
# ..                       ...           ...                ...
# 647      Hardware Specialist      Hardware               None
# 648      Hardware Specialist      Hardware               None
# 649      Hardware Specialist      Hardware               None
# 650  Localization Specialist  Localization               None
# 651  Localization Specialist  Localization               None
# 652  Localization Specialist  Localization               None
# 653                     Tech             8               None
# 654                     Tech             8               None
# 655                     Tech            11               None
# 656                     Tech             8               None
# 657                     Tech             4               None
# 658                     Tech            10               None
# 659                     Tech             5               None
# 660                     Tech            10               None
# 661                     Tech            10         2019-02-14
# 662          Quality Analyst            QM               None
# 663          Quality Analyst            QM               None
# 664          Quality Analyst            QM               None
# 665          Quality Analyst            QM               None
# 666          Quality Analyst            QM               None
# 667  Localization Specialist  Localization               None
# 668               BI Analyst            BI               None
# 669                     Tech             7               None
# 670                     Tech             5               None
# 671  Localization Specialist  Localization               None
# 672                     Tech             5               None
# 673  Localization Specialist  Localization               None
# 674  Localization Specialist  Localization               None
# 675                     Tech             6               None
# 676                     Tech            11               None
#
#                       email_ka specialization_ka specialization2_ka  \
# 0             dnelson@bpcs.com             Fraud               None
# 1            imajougo@bpcs.com   Unknown Charges               None
# 2                 xli@bpcs.com              Tech               None
# 3             mmcghee@bpcs.com          Accounts               None
# 4          agrigoryan@bpcs.com      Call Logging    Unknown Charges
# 5              eserpi@bpcs.com             Fraud               None
# 6          ashakirova@bpcs.com              None               None
# 7            rpreston@bpcs.com              Tech               None
# 8             rsharan@bpcs.com           Billing               None
# 9            shawkins@bpcs.com              Tech            Billing
# 10         ybulhayeva@bpcs.com          Accounts               None
# 11             yzhang@bpcs.com           Billing               None
# 12           mrobledo@bpcs.com   Unknown Charges       Call Logging
# 13            jlarson@bpcs.com          Hardware               None
# 14           jsimpson@bpcs.com          Accounts               None
# 15         mbiryukova@bpcs.com          Accounts               None
# 16           lgrayson@bpcs.com          Accounts               None
# 17              ozolo@bpcs.com           Billing               None
# 18          jeswigart@bpcs.com              Dota              Merch
# 19         kbaranchuk@bpcs.com           Billing               None
# 20               awei@bpcs.com           Billing               None
# 21            dwilkes@bpcs.com             Fraud            Billing
# 22             jjones@bpcs.com              None               None
# 23              mzhou@bpcs.com           Billing               None
# 24              qchen@bpcs.com              Dota           Artifact
# 25           twhitney@bpcs.com           Billing               None
# 26              wchen@bpcs.com              None               None
# 27                yhe@bpcs.com           Billing               None
# 28         asergueeva@bpcs.com           Billing               None
# 29           umarques@bpcs.com           Billing               None
# ..                         ...               ...                ...
# 647        aabdullahi@bpcs.com          Hardware               None
# 648         nkazaklis@bpcs.com          Hardware            Billing
# 649          jsharkey@bpcs.com          Hardware            Billing
# 650             pwang@bpcs.com                                 None
# 651          sglaeser@bpcs.com                                 None
# 652          egardner@bpcs.com                                 None
# 653           nkopysc@bpcs.com          Accounts               None
# 654      etartaglione@bpcs.com          Accounts               None
# 655    Apereiradelima@bpcs.com          Accounts               None
# 656        rrasmussen@bpcs.com          Accounts               None
# 657   roascanioandara@bpcs.com          Accounts               None
# 658  Pespinozaordonez@bpcs.com          Accounts               None
# 659           ksooter@bpcs.com          Accounts               None
# 660         brogowski@bpcs.com          Accounts               None
# 661            shakim@bpcs.com          Accounts               None
# 662         fnaghiyev@bpcs.com          Accounts               None
# 663           oskoryk@bpcs.com          Accounts               None
# 664        frodriguez@bpcs.com          Accounts               None
# 665              mmei@bpcs.com          Accounts               None
# 666            sradke@bpcs.com          Accounts               None
# 667           mharris@bpcs.com                                 None
# 668           bcoplen@bpcs.com                                 None
# 669             mdias@bpcs.com          Accounts               None
# 670         cdinicola@bpcs.com          Accounts               None
# 671          bcozzari@bpcs.com              Null               None
# 672            haltug@bpcs.com          Accounts               None
# 673         mcarneiro@bpcs.com              Null               None
# 674        asandqvist@bpcs.com              Null               None
# 675           sfrench@bpcs.com          Accounts               None
# 676        shernandez@bpcs.com          Accounts               None
#
#     specialization3_ka
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# 5                 None
# 6                 None
# 7                 None
# 8                 None
# 9                 None
# 10                None
# 11                None
# 12                None
# 13                None
# 14                None
# 15                None
# 16                None
# 17                None
# 18                None
# 19                None
# 20                None
# 21                None
# 22                None
# 23                None
# 24               Merch
# 25                None
# 26                None
# 27                None
# 28                None
# 29                None
# ..                 ...
# 647               None
# 648               None
# 649               None
# 650               None
# 651               None
# 652               None
# 653               None
# 654               None
# 655               None
# 656               None
# 657               None
# 658               None
# 659               None
# 660               None
# 661               None
# 662               None
# 663               None
# 664               None
# 665               None
# 666               None
# 667               None
# 668               None
# 669               None
# 670               None
# 671               None
# 672               None
# 673               None
# 674               None
# 675               None
# 676               None
#
# [677 rows x 19 columns]

# %%
ka_df_insert
# Out:
#     first_name  last_name title team separation_date email specialization  \
# 633      Ilona  Winnemore  Tech    6      2017-11-29  None       Accounts
#
#      wfm_id specialization2 specialization3 first_name_ka last_name_ka  \
# 633  BP1135            None            None           NaN          NaN
#
#     title_ka team_ka separation_date_ka email_ka specialization_ka  \
# 633      NaN     NaN                NaN      NaN               NaN
#
#     specialization2_ka specialization3_ka
# 633                NaN                NaN

# %%
cursor = ka_db.cursor()

# log(ka_db,str("Clearing data from :"+ka_table), "INFO")

# delete table first
# cursor.execute("DELETE FROM "+ka_table)
# cursor.commit()

log(ka_db,str("Starting update of :"+ka_table), 'INFO')
a = int(0)
wfmid = 'OKAY...something really bad happened... i did not even enter the try...'
try:
    for index,row in ka_df_insert.iterrows():
        wfmid = row['wfm_id']
        if row['email'] == None:
            log(ka_db,"The wfm_id : " + str(wfmid) + ' has no Email!','WARNING')
        else:
            cursor.execute("INSERT INTO "+ka_table+"("+ka_columns+") VALUES ("+values+")",
                           row['first_name'],
                           row['last_name'],
                           row['title'],
                           row['team'],
                           row['separation_date'],
                           row['email'],
                           row['specialization'],
                           row['wfm_id'],
                           row['specialization2'],
                           row['specialization3']
                          )

            a = int(index)
            cursor.commit()

except:
    log(ka_db,"There was an error executing this service : Cannot commit a row",'ERROR')
    log(ka_db,"The Offending wfm_id is : "+str(wfmid),'ERROR')
    print(wfmid)
    print(row)
else:
    log(ka_db,str(a)+" rows were effected this run.")  
print('***************** DONE *****************')
# Out:
# ***************** DONE *****************

# %%
cursor = ka_db.cursor()

log(ka_db,str("Starting update of :"+ka_table), 'INFO')
a = int(0)
wfmid = 'OKAY...something really bad happened... i did not even enter the try...'
try:
    for index,row in ka_df_update.iterrows():
        counter = int(0)
        queryStatement = "UPDATE " + ka_table + " SET "
        whereStatement = ''
        
        for col, value in row.iteritems():
            #print('1')
            try:
                if '_ka' not in col:
                    # check for wfm_id and do different things with it
                    if 'wfm_id' in col:
                        whereStatement = " WHERE wfm_id = '"
                        whereStatement += value
                        whereStatement += "'"
                        break
                    
                    #print('2')
                    if counter > 0 :
                        #print('3')
                        queryStatement += ", "
                    #print('4')
                    if value is None :
                        #print('5')
                        queryStatement += col
                        queryStatement += " = Null"
                    else:
                        #print('6')
                        queryStatement += col
                        #print('6a')
                        queryStatement += " = '"
                        #print('6b')
                        value = value.replace("'", "''")
                        # print(value)
                        queryStatement += value
                        queryStatement += "'"
                        #print('6c')
                    #print('7')
                    counter += 1
                    #print('8')
            except:
                print('catch error')
                print(col)
                print(value)
        queryStatement += " "
        queryStatement += whereStatement
        # print(queryStatement)

        wfmid = row['wfm_id']
        if row['email'] == None:
            log(ka_db,"The wfm_id : " + str(wfmid) + ' has no Email!','WARNING')
            print('***************** printing out a row *****************')
            print(row['wfmid'])
        else:
            try:
                cursor.execute(queryStatement)
                cursor.commit()
            except:
                print('***************** EXCEPT *****************')
                print(queryStatement)
                log(ka_db,"The Offending query is : "+str(wfmid),'ERROR')
                #print(row[])
except:
    log(ka_db,"There was an error executing this service : Cannot commit a row",'ERROR')
    log(ka_db,"The Offending wfm_id is : "+str(wfmid),'ERROR')
    print('***************** EXCEPT *****************')
    print(queryStatement)
    #print(row)
else:
    log(ka_db,str(a)+" rows were effected this run.")  
    
print('***************** DID THIS HAPPEN? *****************')
# Out:
# ***************** DID THIS HAPPEN? *****************

# %%
log(ka_db,str("Script complete. Going to sleep."), "INFO")
cursor.close()
ka_db.disconnect()
